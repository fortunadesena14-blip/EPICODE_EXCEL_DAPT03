# %%
# ESERCIZI W9D1 
# esercizio iniziale - trovare task e scrivere passaggi di un possibile algortimo.
'''
Spesa
1. Preparare una lista delle cose da comprare.
2. Controllare se hai soldi / carta nel portafoglio.
3. Andare al supermercato.
4. Prendere un carrello o un cestino.
5. Entrare e percorrere i vari reparti.
6. Per ogni prodotto nella lista:
Cercare il prodotto sullo scaffale.
Se lo trovi, mettilo nel carrello.
Se non lo trovi, valuta un sostituto oppure salta.
7. Controllare se mancano elementi della lista.
8. Andare alla cassa.
9. Mettere i prodotti sul nastro.
10. Pagare.
11. Ritirare la spesa e tornare a casa.


Studiare.
1. Scegliere il concetto da studiare.
2. Individuare una fonte affidabile (libro, appunti, video).
3. Leggere/guardare la spiegazione una prima volta.
4. Annotare le parti poco chiare.
5. Cercare chiarimenti sulle parti difficili (altre fonti, esempi…).
6. Rileggere la spiegazione, ora con più contesto.
7. Scrivere una sintesi con parole proprie.
8. Creare uno o due esempi pratici del concetto.
9. Verificare la comprensione rispondendo a qualche domanda o esercizio.
10. Ripassarlo dopo qualche ora o il giorno dopo.


Acquisto di uno snack.
1. Avvicinarsi al distributore.
2. Controllare il prezzo dello snack desiderato.
3. Verificare di avere abbastanza monete o carta.
4. Inserire il denaro o la carta.
5. Digitare il codice dello snack scelto.
6. Attendere che la macchina verifichi la disponibilità.
7. Se lo snack è disponibile, il distributore lo rilascia.
8. Raccogliere lo snack dal vano.
9. Prendere eventuale resto.
10. Terminare l’operazione.
'''

# Esercizio Abbiamo 25 studenti; 
# 1. memorizzare questo dato in una variabile. 
studenti = 25
# usare la funzione print
print("Gli studenti sono", studenti)
# 3. arrivano altri studenti
studenti_aggiuntivi = 3
# 4. effettuana la somma degli studenti e stampa il risultato
totale_studenti = studenti + studenti_aggiuntivi
print("Il numero di studenti è", totale_studenti)
# 5. crea una stringa
corso = "Epicode"
print("Il nome del corso è", corso)
# 6. la variabile x = 10, incrementale di 2 e moltiplicala per 3
x = 10
x += 2
x *= 3
print("Il risultato finale è",x)
# 7. crea stringhe e usa len
str1 = "Windows" 
str2 = "Excel" 
str3 = "Powerpoint" 
str4 = "Word"
print("La parola Windows è composta dal seguente numero di caratteri:", len(str1))
print("La parola Excel è composta dal seguente numero di caratteri:", len(str2))
print("La parola PowerPoint è composta dal seguente numero di caratteri:", len(str3))
print("La parola Word è composta dal seguente numero di caratteri:", len(str4))
# 8. Calcolare e stampare a video quanti secondi ci sono in un anno non bisestile.
secondi_in_un_anno_non_bisestile = 365 * 24 * 60 * 60
print("I secondi in un anno bisestile sono pari a:", secondi_in_un_anno_non_bisestile)
# 9. 
my_string = "I am studying Python"
# Trasformarla in modo che tutti i caratteri siano maiuscoli (uppercase) 
print(my_string.upper())
# Trasformarla in modo che tutti i caratteri siano minuscoli (lowercase)
print(my_string.lower())
#Sostituire la sottostringa "Python" con la stringa "a lot" 
nuovastringa = my_string.replace("Python", "a lot") #sostituire una parte di stringa
print(nuovastringa)
# Usare il metodo .strip(); cambia qualcosa? Perché? 
# questa funzione serve per eliminare spazi o caratteri dai bordi a dx e sx, ma nel nostro caso non ci sono per cui non cambia nulla.
print(my_string.strip())
# Usare il metodo .split() per trovare tutte le parole (token)
# questa funzione è diversa, perché divide l'intera stringa in tutte le parole che la costituiscono.
parole1 = my_string.split(" ") 
parole2 = nuovastringa.split(" ") 
print(parole1)
print(parole2)
# Esercizio (1/2) Abbiamo due liste, una di studenti e una di corsi: 
stu = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"] 
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
# Aggiungiamo i corsi mancanti
corsi.append("Frontend")
corsi.append("Cybersecurity")
print(corsi)
# Out:
# Gli studenti sono 25
# Il numero di studenti è 28
# Il nome del corso è Epicode
# Il risultato finale è 36
# La parola Windows è composta dal seguente numero di caratteri: 7
# La parola Excel è composta dal seguente numero di caratteri: 5
# La parola PowerPoint è composta dal seguente numero di caratteri: 10
# La parola Word è composta dal seguente numero di caratteri: 4
# I secondi in un anno bisestile sono pari a: 31536000
# I AM STUDYING PYTHON
# i am studying python
# I am studying a lot
# I am studying Python
# ['I', 'am', 'studying', 'Python']
# ['I', 'am', 'studying', 'a', 'lot']
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
